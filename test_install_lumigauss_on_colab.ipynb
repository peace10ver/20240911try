# %% [markdown]
# <a href="https://colab.research.google.com/github/peace10ver/20240911try/blob/main/test_install_lumigauss_on_colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch

torch.version.cuda
# Out:
# '12.6'

# %%
# !git clone https://github.com/joaxkal/lumigauss.git --recursive
# %cd lumigauss
# Out:
# fatal: destination path 'lumigauss' already exists and is not an empty directory.
# /content/lumigauss

# %%
# !pip install torch==2.6.0 torchvision==0.21.0 torchaudio==2.6.0 --index-url https://download.pytorch.org/whl/cu124
# Out:
# Looking in indexes: https://download.pytorch.org/whl/cu124
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 107.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 62.8 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 133.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.7 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 4.0 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 5.3 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 13.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.1 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 5.4 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 188.7/188.7 MB 5.6 MB/s eta 0:00:00
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 99.1/99.1 kB 9.2 MB/s eta 0:00:00
# ...

# %%
import torch

torch.version.cuda
# Out:
# '12.4'

# %%
# !pip install tqdm plyfile scipy pandas tensorboard
# Out:
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 43.3/43.3 kB 3.1 MB/s eta 0:00:00
# ...

# %%
# !pip install opencv-python einops matplotlib imageio[ffmpeg] lpips scikit-image
# Out:
# ...
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 53.8/53.8 kB 3.1 MB/s eta 0:00:00
# ...

# %%
# !pip install submodules/diff-surfel-rasterization
# Out:
# Processing ./submodules/diff-surfel-rasterization
#   Preparing metadata (setup.py) ... done
# ...
#   Created wheel for diff_surfel_rasterization: filename=diff_surfel_rasterization-0.0.0-cp312-cp312-linux_x86_64.whl size=3349954 sha256=08c3fab75ca8428ac6aa31c4942dc9b0b1b97eadc983ec03e08cb81d6fe2d42d
#   Stored in directory: /root/.cache/pip/wheels/84/09/3a/32fe4fc3711176aa220adb724f4c18662a18c6c3edb12db4f9
# Successfully built diff_surfel_rasterization
# ...

# %%
# !pip install -e submodules/simple-knn
# Out:
# Obtaining file:///content/lumigauss/submodules/simple-knn
#   Preparing metadata (setup.py) ... done
# ...
#   Running setup.py develop for simple_knn
# ...
